# %%
import pandas as pd

# %%
df = pd.read_csv("creditcard_fraud_detection.csv")

# %%
df.shape
# Out:
# (284807, 31)

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
